# %% [markdown]
# <a href="https://colab.research.google.com/github/ramiromotajunior-glitch/stirngs_metodos/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = "ANA"
print(nome.lower())
# Out:
# ana

# %%
nome ="  MARIA  EDUARDA ALMEIDA"
email  ='MARIA.ALMEIDA@EMPRESA.COM'

#1-Remover espaços extras
nome = nome.strip()
email = email.strip()

#2- converter para minusculo
nome  = nome. lower()
email = email.lower()
#3 - substituir o  email
email =email.replace("empresa.com","gmail.com")
#4 -qtd de caracteres
quantidades= len(nome)
#5  - ultimo/primeiro
ultima_letra=nome[-1]
primeira_letra= nome[0]
print("nome tratado:",nome)
print("emailtratado:",email)
print("quantidade de caracteres:",quantidades)
print("ultima letra:",ultima_letra)
print("primeiraletra:",primeira_letra)
# Out:
# nome tratado: maria  eduarda almeida
# emailtratado: maria.almeida@gmail.com
# quantidade de caracteres: 22
# ultima letra: a
# primeiraletra: m

# %%
produto=input("digite seu produto:")
categoria=input('digite sua categoria:')
codigo=input("digite seu codigo:")
produto=produto.strip()
categoria=categoria.strip()
codigo=codigo.strip()
#2categoria minusculas
categoria= categoria.lower()

#3 maisculas e substituir
codigo = codigo.upper()
codigo= codigo.replace("_","")
#4quantidade de caracteres
quantidade= len(produto)

#5-primeira letra e 4primeiros caracteres do produto
primeira_letra=produto[0]
primeiros_cod=codigo[:4]
print("produto",produto)
print("categoria",categoria)
print("codigo",codigo)
print('quntidade de caracteres:',quantidade)
print("primeira letra:",primeira_letra)
print("4 primeiros caracteres do cod:",primeiros_cod)
# Out:
# digite seu produto:jk zknvck n
# digite sua categoria:çkakfvnk\ x
# digite seu codigo:jk\aljrhvfia
# produto jk zknvck n
# categoria çkakfvnk\ x
# codigo JK\ALJRHVFIA
# quntidade de caracteres: 11
# primeira letra: j
# 4 primeiros caracteres do cod: JK\A
